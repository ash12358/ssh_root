# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %%
cd /drive/My\ Drive/ssh/
# Out:
# /drive/My Drive/ssh

# %%
# !chmod +x setup_screen
# !chmod +x setup_Sakura

# %%
# !cat /etc/hosts
# Out:
# 127.0.0.1	localhost
# ::1	localhost ip6-localhost ip6-loopback
# fe00::0	ip6-localnet
# ff00::0	ip6-mcastprefix
# ff02::1	ip6-allnodes
# ff02::2	ip6-allrouters
# 172.28.0.2	85c58650bc0c
# 115.238.185.30 frp.tcotp.cn

# %%
# !./setup_screen

# %%
# !cat nohup.out
# Out:
#  ____        _                      _____
# / ___|  __ _| | ___   _ _ __ __ _  |  ___| __ _ __
# \___ \ / _` | |/ / | | | '__/ _` | | |_ | '__| '_ \
#  ___) | (_| |   <| |_| | | | (_| | |  _|| |  | |_) |
# |____/ \__,_|_|\_\\__,_|_|  \__,_| |_|  |_|  | .__/
#                                              |_|
# === Sakura Frp Client ===
# 官方网址: https://www.natfrp.org
# 检测更新中...
# 当前Sakura-frp版本: 2300
# 发布Sakura-frp版本: 2300
# 账号>密码>>正在尝试登陆，账号: ash12358
# >登陆成功
#                                                    ____        _                      _____
#                                                   / ___|  __ _| | ___   _ _ __ __ _  |  ___| __ _ __
#   欢迎使用 Sakura Frp                             \___ \ / _` | |/ / | | | '__/ _` | | |_ | '__| '_ \
#                                                    ___) | (_| |   <| |_| | | | (_| | |  _|| |  | |_) |
#   服务器线路列表                                  |____/ \__,_|_|\_\\__,_|_|  \__,_| |_|  |_|  | .__/
# ...

# %%
# !/etc/init.d/networking restart
# Out:
# /bin/bash: /etc/init.d/networking: No such file or directory

# %%
# !rm /etc/ssh/sshd_config
# !cp sshd_config /etc/ssh/
# !cp ssh_config /etc/ssh/
# !service ssh start
# !cp jupyter_notebook_config.py /root/.jupyter/
# !echo -e '111111\n111111' | passwd
# !chmod +x Sakura_frpc_linux_amd64

# # !cp shadowsocks.json /etc/
# # !rm /usr/local/lib/python2.7/dist-packages/shadowsocks/crypto/openssl.py
# # !cp openssl.py /usr/local/lib/python2.7/dist-packages/shadowsocks/crypto/
# Out:
#  * Starting OpenBSD Secure Shell server sshd
#    ...done.
# Enter new UNIX password: Retype new UNIX password: passwd: password updated successfully

# %%
# !./setup_auto9

# %%
# !./Sakura_frpc_linux_amd64 --su=ash12358 --sp=12358a --sid=4 &

# %%
# !python2 sunny.py --clientid=aafb9cead61c5526#255dff4caefd6958##,d7897d59dfb971f6.
# Out:
# 欢迎使用内网穿透 python-ngrok v1.42
# Ctrl+C 退出
# 认证成功,正在连接服务器...
# 隧道建立成功: tcp://free.idcfengye.com:10259
